# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/1_Assignment/blob/main/set_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s={1,2,3}
s.add(40)
print(s)
# Out:
# {40, 1, 2, 3}

# %%
s={1,2,3,4,5}
l=[10,20,30,40]
s.update(l,range(0))
print(s)
# Out:
# {1, 2, 3, 4, 5, 10, 20, 30, 40}

# %%
x={1,2,3,4,5,10,3,4,90,10}
y={3,2,8,6,10,30,70}
print(x.union(y))
print(x|y)
# Out:
# {1, 2, 3, 4, 5, 70, 6, 8, 10, 90, 30}
# {1, 2, 3, 4, 5, 70, 6, 8, 10, 90, 30}

# %%
a={11,22,33,44,55}
b={11,22,33,55,88,99}
print(a.intersection(b))
print(a&b)
# Out:
# {33, 11, 22, 55}
# {33, 11, 22, 55}

# %%
a={'x','y','z'}
b={'x','s','z','d'}
print(a.difference(b))
print(b.difference(a))
print(a-b)
# Out:
# {'y'}
# {'s', 'd'}
# {'y'}

# %%
x={1,2,3,4,5}
y={10,2,3,4,50,5}
print(x.symmetric_difference(y))
print(x^y)
# Out:
# {1, 50, 10}
# {1, 50, 10}

# %%
s=set("python")
print(s)
print ('d'in s)
print('y' in s)
# Out:
# {'n', 't', 'y', 'h', 'p', 'o'}
# False
# True

# %%
s=(x*x for x in range(5))
print(s)
# Out:
# <generator object <genexpr> at 0x7dc17852cfb0>

# %% [markdown]
# Write a Program to eliminate Duplicates Present in the List?

# %%
l=[1,2,3,4,5,6,1,20,30,4,5,70,40,3]
print(x)
print(type(x))
# Out:
# {1, 2, 3, 4, 5, 6, 70, 40, 20, 30}
# <class 'set'>

# %% [markdown]
#  Write a Program to Print different Vowels Present in the given Word?(Using intersection method

# %%
words=input("Enter word:")
vowels={'a','e','i','o','u'}
print(set(words).intersection(vowels))
# Out:
# Enter word:Shrisha
# {'a', 'i'}
