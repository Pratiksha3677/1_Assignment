# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/1_Assignment/blob/main/Basic_python_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s={1,2,3}
s.add(40)
print(s)
# Out:
# {40, 1, 2, 3}

# %%
s={1,2,3,4,5}
l=[10,20,30,40]
s.update(l,range(0))
print(s)
# Out:
# {1, 2, 3, 4, 5, 10, 20, 30, 40}

# %%
x={1,2,3,4,5,10,3,4,90,10}
y={3,2,8,6,10,30,70}
print(x.union(y))
print(x|y)
# Out:
# {1, 2, 3, 4, 5, 70, 6, 8, 10, 90, 30}
# {1, 2, 3, 4, 5, 70, 6, 8, 10, 90, 30}

# %%
a={11,22,33,44,55}
b={11,22,33,55,88,99}
print(a.intersection(b))
print(a&b)
# Out:
# {33, 11, 22, 55}
# {33, 11, 22, 55}

# %%
a={'x','y','z'}
b={'x','s','z','d'}
print(a.difference(b))
print(b.difference(a))
print(a-b)
# Out:
# {'y'}
# {'s', 'd'}
# {'y'}

# %%
x={1,2,3,4,5}
y={10,2,3,4,50,5}
print(x.symmetric_difference(y))
print(x^y)
# Out:
# {1, 50, 10}
# {1, 50, 10}

# %%
s=set("python")
print(s)
print ('d'in s)
print('y' in s)
# Out:
# {'n', 't', 'y', 'h', 'p', 'o'}
# False
# True

# %%
s=(x*x for x in range(5))
print(s)
# Out:
# <generator object <genexpr> at 0x7dc17852cfb0>

# %% [markdown]
# Write a Program to eliminate Duplicates Present in the List?

# %%
l=[1,2,3,4,5,6,1,20,30,4,5,70,40,3]
print(x)
print(type(x))
# Out:
# {1, 2, 3, 4, 5, 6, 70, 40, 20, 30}
# <class 'set'>

# %% [markdown]
#  Write a Program to Print different Vowels Present in the given Word?(Using intersection method

# %%
words=input("Enter word:")
vowels={'a','e','i','o','u'}
print(set(words).intersection(vowels))
# Out:
# Enter word:Shrisha
# {'a', 'i'}

# %%
s='Pratiksha'
s[0]
s[-1]
# Out:
# 'a'

# %%
s='Learning python is very very easy!!!'
s[1:7:1]
s[2:5:1]
s[::]
s[::-1]
s[1000:2:-1]
s[9:14:1]
# Out:
# 'pytho'

# %%
len(s)
# Out:
# 36

# %%
s=input('Enter String:')
i=0
while i<len(s):
 print(s[i],end='')
 i+=1
print('\n Backword direction')
j=len(s)-1
while j>=0:
  print(s[j],end='')
  j-=1
# Out:
# Enter String:Shriniwas
# Shriniwas
#  Backword direction
# sawinirhS

# %%
s="pratiksha"
len(s)
# Out:
# 9

# %%
s='data'
'a' in s
'f' not in s
'z' in s
# Out:
# False

# %%
a=input("First string:")    #comparision of string
b=input("second string:")
if a<b:
  print("first string is smaller than second string")
else:
    print("first string is greater than second string")
# Out:
# First string:shri
# second string:shriniwas
# first string is smaller than second string

# %% [markdown]
# Removing Spaces from the String:
# 1)rstrip()-->To remove spaces at right hand side.
#
# lstrip()--> To remove spaces at left hand side.
#
# strip()-->To remove spaces both sides.

# %%
city=input("Enter your city Name:")
scity=city.strip()
if scity=='Hyderabad':
    print("Hello Hyderbadi..Adab")
elif scity=='Chennai':
    print("Hello Madrasi...Vanakkam")
elif scity=="Bangalore":
    print("Hello Kannadiga...Shubhodaya")
else:
  print("your entered city is invalid")
# Out:
# Enter your city Name:   Hyderabad
# Hello Hyderbadi..Adab

# %%
s='  data '
s.rstrip()
s.lstrip()
s.strip()
# Out:
# 'data'

# %%
s='data'     ## find(): Returns index of first occurrence of the given substring. If it is not available then we will
s.find('data')
s.find('t')
s.find('Z')
# Out:
# -1

# %%
## syntax: s.find(substring,bEgin,end)
s='pratiksha'
s.find('t',0,8)
# Out:
# 3

# %% [markdown]
# index() method is exactly same as find() method except that if the specified substring is not available then we will get ValueError

# %%
s='data'
s.index('d')
# Out:
# 0

# %%
s=input("Entermainstring:")
subs=input("Entersubstring:")
flag=False
pos=0
n=len(s)
while True:
  pos=s.find(subs,pos,n)
  if pos==-1:
    break
  print("Found at position",pos)
  pos=pos+1
  flag=True
if flag==False:
  print("Not Found")
# Out:
# Entermainstring:pratiksha
# Entersubstring:a
# Found at position 2
# Found at position 8
