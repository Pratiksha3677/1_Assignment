# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/1_Assignment/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Remove the first and last charecter in string "Learning"

# %%
s="Learning"
print(s[1:7])
# Out:
# earnin

# %% [markdown]
# 2.Get every 2nd charecter from the string "Developer"

# %%
s="Developer"
print(s[0::2])
# Out:
# Dvlpr

# %% [markdown]
# 3.Slice "Artificial to get "Art" and "ficial" seprately

# %%
s = "Artificial"
print(s[:3])
print(s[4:])
# Out:
# Art
# ficial

# %% [markdown]
# 4.Given word = "PythonProgramming" extract "python" and "Programming" using slicing

# %%
s="PythonProgramming"
print(s[:6])
print(s[6:])
# Out:
# Python
# Programming

# %% [markdown]
# 5.Slice string "DataScience" to get "Science" only

# %%
s="DataScience"
print(s[4:])
# Out:
# Science
